# %% [markdown]
# # Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
# Write your code here
print("name: afsar ali\nfather name: sultan\ndate of birth: 06-04-1988")
# Out:
# name: afsar ali
# father name: sultan
# date of birth: 06-04-1988

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
# Write your code here
bio = "my name is afsar ali. i am learning python programming language. i love to code." 
print(bio)
# Out:
# my name is afsar ali. i am learning python programming language. i love to code.

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
# Write your code here
# addition
a = 10
b = 5
print(a + b)
# Out:
# 15

# %%
2+5
# Out:
# 7

# %%
val1 = 12
val2 = 13
print(val1 + val2)
# Out:
# 25

# %%
# subtraction
5-3
# Out:
# 2

# %%
a = 10
b = 5
print(a-b)
# Out:
# 5

# %%
# multiplication
4 * 2
# Out:
# 8

# %%
2**3 # 2*2*2
# Out:
# 8

# %%
2**5 # 2*2*2*2*2
# Out:
# 32

# %%
100 / 20
# Out:
# 5.0

# %%
# division
10 / 2
# Out:
# 5.0

# %%
VAL1 = 100
VAL2 = 50
print(VAL1 / VAL2)
# Out:
# 2.0

# %% [markdown]
# 4. Completes the following steps of small task:
#     - Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
#     - Mention Variable of Total Marks and assign 300 to it
#     - Calculate Percentage

# %%
# Write your code here
#1. subjects marks
english = 85
math = 90
islamiyat = 89

# 2 total marks = 300
total_marks = 300
# 3. obtained marks
obtained_marks = english + math + islamiyat
# 4. percentage
percentage = (obtained_marks / total_marks) * 100
# 5.percentage
print("percentage:", percentage,"%")
# Out:
# percentage: 88.0 %
