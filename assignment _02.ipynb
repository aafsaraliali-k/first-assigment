# %% [markdown]
# # Part -2 Python Basics (Conditional Statements)

# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
#Type your code here
# getting input from the user
salar = float(input("enter your salar: "))
service_years = int(input("enter your years of service: "))
# checking the condition if service_years > 5:
if service_years > 5:
    bonus = salar * 0.05
    print(f"your bonus is: {bonus}") 
else:
    print("no bonus for you")
# Out:
# your bonus is: 2500.0

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
 #Type your code here 
# asking age from user
age = int(input("enter your age: "))
# check condition
if age >= 18:
    print("you are eligible to vote") 
else:
    print("you are not eligible to vote")
# Out:
# you are not eligible to vote

# %%
print(age)
# Out:
# 16

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
#Type your code here
# asking number from user
num = int(input("enter a number: "))
# checking condition
if num % 2 == 0:
    print(f"{num} is even number")
# Out:
# 20 is even number

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
#Type your code here
num = int(input("enter a number: "))
if num % 7 == 0:
    print(f"{num} is divisible by 7")
else:
    print(f"{num} is not divisible by 7")
# Out:
# 10 is not divisible by 7

# %%
print(num)
# Out:
# 10

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
#Type your code here
number = int(input("enter a number: "))
if number % 5 == 0:
    print("hello") 
else:
    print("bye")
# Out:
# bye

# %%
print(number)
# Out:
# 7

# %% [markdown]
# 7) Write a program to display the last digit of a number.

# %%
#Type your code  here
#asking number from user
num = int(input("enter a number: "))
# check last digit
last_digit = num % 10
if last_digit % 3 == 0:
    print("last digit is divisible by 3")
# Out:
# last digit is divisible by 3

# %% [markdown]
# 9.Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
#Type your code here 
# take value from user
length = float(input("enter length : "))
breadth = float(input("enter breadth : ")) 
# check condition for square 
if length == breadth:
    print("it is a square") 
else:
    print("it is a rectangle")
# Out:
# it is a rectangle

# %%
print(length)
# Out:
# 8.0

# %% [markdown]
# 10) Take two int values from user and print greatest among them.

# %%
# Type your code here
# tow int values from user
num1 = int(input("enter first number: "))
num2 = int(input("enter second number: "))
# check which is greater
if num1 > num2:
    print(f"{num1} is greater")
# Out:
# 9 is greater

# %%
print(num2)
# Out:
# 8

# %% [markdown]
# 11) A shop will give discount of 10% if the cost of purchased quantity is more than 1000.
# Ask user for quantity
# Suppose, one unit will cost 100.
# Judge and print total cost for user.

# %%
#Type your code here
# ask user for quantity 
quantity = int(input("enter the quantity: "))
# calculat total cost (100 per unit)
total_cost = quantity * 100
# apply 10% discount if total_cost is more than 1000
if total_cost > 1000:
    discount = total_cost * 0.10
    total_cost = total_cost - discount 
    print("you get a 10% discount!")
print("the total cost for the user is: ", total_cost)
# Out:
# you get a 10% discount!
# the total cost for the user is:  45000.0

# %% [markdown]
# 12) A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
#Type your code here
# asking from user
marks = int(input("enter your marks: "))
# Grading systems condition
if marks < 25:
    print("grade: f")
elif marks >= 25 and marks < 45:
    print("grade e") 
elif marks >= 45 and marks < 50:
    print("grade: d")
elif marks >= 50 and marks < 60:
    print("garde: c") 
elif marks >= 60 and marks < 80:
    print("grade: b") 
else:
    # as above 80 will begrade a
    print("grade: a")
# Out:
# grade: a

# %%
print(marks)
# Out:
# 95

# %% [markdown]
# 14)A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
# Take following input from user
#
# - Number of classes held
#
# - Number of classes attended.
#
# And print
#
# - percentage of class attended
#
# - Is student is allowed to sit in exam or not.

# %%
#Type your code here
# input from user
held = int(input("enter number of classes held: "))
attended = int(input("enetr number of classes attended: "))
att_per = (attended / held) * 60
print(f"percentage of classes attended: {att_per}%") 
if att_per >= 75:
    print("is studenets allowed to sit in exam? yes") 
else:
    print("is students allowed to sit in exam? no")
# Out:
# percentage of classes attended: 60.0%
# is students allowed to sit in exam? no

# %% [markdown]
# 15) Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
#Type your code here
 # information from user 
attended = int(input("attended classes: "))
medical = input("medical issue? (y/n") 
# percentage formula
per = (attended / held) * 100
print(f"attendance: {per}%") 
# final decision (medical logic)
if per >= 75:
    print("allowed to sit in exam: yes") 
elif medical == "y" or medical == "y": 
    # attendance below cause of medical issue 
    print("allowed due to medical cause: yes") 
else: 
    print("allowed to sit in exam: no")
# Out:
# attendance: 83.33333333333334%
# allowed to sit in exam: yes

# %% [markdown]
# 16) Write a program to check if a year is leap year or not.
#
# If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
#Type your code here
# ask year from user
year = int(input("enter a year: "))
# logic of leap year
if (year % 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print(f"{year} is a leap year") 
else:
    print(f"{year} is not a leap year")
# Out:
# 2021 is not a leap year

# %% [markdown]
# 17) Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
#Type your code here
# inputs (age,gender,marital status)
age = int(input("enter age: "))
gender = input("enter gender (m or f): ") 
satatus = input("married? (y or n): ") 
# check logic rules
if gender == "f" or gender == "f":
    print("place of services: urban areas") 
elif gender == "m" or gender == "m":
    if age  >= 20 and age <= 40:
        print("place of service: anywhere") 
    elif age > 40 and age <= 60:
        print("place of service: anywhere") 
    elif age > 40 and age <= 60:
        print("place of service: urban areas") 
else:
    print("error")
# Out:
# error

# %% [markdown]
# 6) Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria :
#      Unit                                                     Price
# uptp 100 units                                             no charge
# Next 200 units                                              Rs 5 per unit
# After 200 units                                             Rs 10 per unit
# (For example if input unit is 350 than total bill amount is Rs.3500
# (For example if input unit is 97 than total bill amount is Rs.0
# (For example if input unit is 150 than total bill amount is Rs.750

# %%
#type code here
# ask unit from user
units = int(input("enter number of units: "))
# bill calculation
bill = 0
if units <= 100:
    bill = 0
elif units <= 300:
    # first 100 free,remaining per 5 rs.
    bill = (units - 100) * 5
else:
    # till 300 of bill (200 * 5 = 1000) + 300 above units per  10 rs.
    bill  = 1000 + (units - 300) * 10
# final bill
print(f"total bill amount is: rs. {bill}")
# Out:
# total bill amount is: rs. 500

# %% [markdown]
# 13) Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
#Type your code here
# age of three persons
p1 =int(input("enter age of person 1: "))  
p2 =int(input("enter age of person 2: "))
p3 =int(input("enter age of person 3: "))
# check the oldest one
if p1 >= p2 and p1 >= p3:
    oldest = p2
else:
    oldest = p3
# check the youngest one
if p1 <= p2 and p1 <= p3:
    youngest = p1
elif p2 <= p1 and p2 <= p3:
    youngest = p2
else:
    youngest = p3
    ## result
print(f"the youngest person is: {youngest}")
# Out:
# the youngest person is: 40
